# %% [markdown]
# # Convolutional Neural Network (CNN)

# %%
# import tensorflow

import tensorflow as tf 
from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
(train_images,train_labels),(test_images,test_labels)= datasets.cifar10.load_data()

# normalize pixel values to be between 0 and 1
train_images,test_images = train_images /255.0,test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#  20955136/170498071 ━━━━━━━━━━━━━━━━━━━━ 2:39:39 64us/step
# ---------------------------------------------------------------------------
# ContentTooShortError                      Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\keras\src\utils\file_utils.py:354, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     353 try:
# --> 354     urlretrieve(origin, download_target, DLProgbar())
#     355 except urllib.error.HTTPError as e:
#
# File ~\anaconda3\Lib\urllib\request.py:280, in urlretrieve(url, filename, reporthook, data)
#     279 if size >= 0 and read < size:
# --> 280     raise ContentTooShortError(
#     281         "retrieval incomplete: got only %i out of %i bytes"
#     282         % (read, size), result)
#     284 return result
#
# ContentTooShortError: <urlopen error retrieval incomplete: got only 20951925 out of 170498071 bytes>
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 (train_images,train_labels),(test_images,test_labels)= datasets.cifar10.load_data()
#       3 # normalize pixel values to be between 0 and 1
#       4 train_images,test_images = train_images /255.0,test_images / 255.0
#
# File ~\anaconda3\Lib\site-packages\keras\src\datasets\cifar10.py:70, in load_data()
#      68 dirname = "cifar-10-batches-py-target"
#      69 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 70 path = get_file(
#      71     fname=dirname,
#      72     origin=origin,
#      73     extract=True,
#      74     file_hash=(  # noqa: E501
#      75         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      76     ),
#      77 )
#      79 num_train_samples = 50000
#      81 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\file_utils.py:358, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir, force_download)
#     356         raise Exception(error_msg.format(origin, e.code, e.msg))
#     357     except urllib.error.URLError as e:
# --> 358         raise Exception(error_msg.format(origin, e.errno, e.reason))
#     359 except (Exception, KeyboardInterrupt):
#     360     if os.path.exists(download_target):
#
# Exception: URL fetch failure on https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz: None -- retrieval incomplete: got only 20951925 out of 170498071 bytes

# %%
class_names = ['aeroplane','automobile','bird','cat','deer'
               ,'dog','frog','horse','ship','truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # the Cifar labels happen to be array
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()
